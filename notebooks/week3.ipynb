# %% [markdown]
# # Week 3 Notes

# %% [markdown]
# Go over proofs: strong markov to reflection principle
#
# Why couldn't this work for fractional Brownian motion?
# Reflection requires
# - independence of future increments
# - symmetry
# - restarting the process
#
# fBM immediately loses one of these.
