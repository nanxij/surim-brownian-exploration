# %% [markdown]
# Plan going forward!
#
# - Week 4: Fractional Brownian motion; covariance, Hurst parameter, and why the semimartingale property is lost
# - Week 5: Young integration and the idea of enhancing a path with iterated integrals; introduction to rough paths
# - Week 6: Signatures, rough differential equations, and applications to rough volatility and sequential data
# - Week 7:
# - Week 8: Simulations, synthesis, and writing
#
# sims:
#
# - compare sample paths for different Hurst parameters (done)
# - estimate quadratic variation
# - illustrate convergence (or failure) of Riemann sums
# - visualize low-order iterated integrals or signatures for simple curves
# - compare simulated rough-volatility paths with classical stochastic-volatility paths
